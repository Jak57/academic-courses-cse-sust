# %%
import pandas as pd
import matplotlib.pyplot as plt

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df_init = pd.read_csv("/content/drive/MyDrive/dataset_data_science/brfss - brfss.csv", index_col=0)
df_init
# Out:
#          age     weight2     wtyrago   wtkg2   htm3  sex
# 0       39.0   88.636364   88.636364   88.64  180.0    1
# 1       64.0   75.000000   84.545455   75.00  155.0    2
# 2       87.0   61.818182   63.636364   61.82    NaN    2
# 3       51.0  100.000000  100.000000  100.00  183.0    1
# 4       35.0   63.636364   61.363636   63.64  170.0    2
# ...      ...         ...         ...     ...    ...  ...
# 414504   NaN         NaN         NaN     NaN  170.0    2
# 414505  62.0   86.363636         NaN   86.36  168.0    2
# 414506  75.0   59.090909   63.636364   59.09  165.0    2
# 414507   NaN         NaN         NaN     NaN    NaN    2
# 414508   NaN         NaN         NaN     NaN    NaN    2
#
# [414509 rows x 6 columns]

# %%
df = df_init.drop(['sex'], axis=1)
df
# Out:
#          age     weight2     wtyrago   wtkg2   htm3
# 0       39.0   88.636364   88.636364   88.64  180.0
# 1       64.0   75.000000   84.545455   75.00  155.0
# 2       87.0   61.818182   63.636364   61.82    NaN
# 3       51.0  100.000000  100.000000  100.00  183.0
# 4       35.0   63.636364   61.363636   63.64  170.0
# ...      ...         ...         ...     ...    ...
# 414504   NaN         NaN         NaN     NaN  170.0
# 414505  62.0   86.363636         NaN   86.36  168.0
# 414506  75.0   59.090909   63.636364   59.09  165.0
# 414507   NaN         NaN         NaN     NaN    NaN
# 414508   NaN         NaN         NaN     NaN    NaN
#
# [414509 rows x 5 columns]

# %%
df = df.dropna()
df
# Out:
#          age     weight2     wtyrago   wtkg2   htm3
# 0       39.0   88.636364   88.636364   88.64  180.0
# 1       64.0   75.000000   84.545455   75.00  155.0
# 3       51.0  100.000000  100.000000  100.00  183.0
# 4       35.0   63.636364   61.363636   63.64  170.0
# 5       62.0   70.454545   70.454545   70.45  173.0
# ...      ...         ...         ...     ...    ...
# 414499  61.0   81.818182   86.363636   81.82  175.0
# 414500  57.0   56.818182   58.181818   56.82  168.0
# 414501  18.0   68.181818   63.636364   68.18  178.0
# 414503  42.0   90.454545   90.909091   90.45  163.0
# 414506  75.0   59.090909   63.636364   59.09  165.0
#
# [385974 rows x 5 columns]

# %%
df.weight2.describe()
# Out:
# count    385974.000000
# mean         79.061463
# std          19.514283
# min          20.000000
# 25%          64.545455
# 50%          77.272727
# 75%          90.909091
# max         300.000000
# Name: weight2, dtype: float64

# %%
df.age.mean()
# Out:
# 54.8524874732495

# %%
df.age.mode()
# Out:
# 0    60.0
# dtype: float64

# %% [markdown]
# # Scaling

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
norm_array = scaler.fit_transform(df)
norm_array
# Out:
# array([[0.25925926, 0.24512987, 0.20625889, 0.24514286, 0.68      ],
#        [0.56790123, 0.19642857, 0.19345661, 0.19642857, 0.53714286],
#        [0.40740741, 0.28571429, 0.24182077, 0.28571429, 0.69714286],
#        ...,
#        [0.        , 0.17207792, 0.12802276, 0.17207143, 0.66857143],
#        [0.2962963 , 0.25162338, 0.21337127, 0.25160714, 0.58285714],
#        [0.7037037 , 0.13961039, 0.12802276, 0.13960714, 0.59428571]])

# %%
df_s = pd.DataFrame(norm_array, columns=df.columns)

# %%
df_s
# Out:
#              age   weight2   wtyrago     wtkg2      htm3
# 0       0.259259  0.245130  0.206259  0.245143  0.680000
# 1       0.567901  0.196429  0.193457  0.196429  0.537143
# 2       0.407407  0.285714  0.241821  0.285714  0.697143
# 3       0.209877  0.155844  0.120910  0.155857  0.622857
# 4       0.543210  0.180195  0.149360  0.180179  0.640000
# ...          ...       ...       ...       ...       ...
# 385969  0.530864  0.220779  0.199147  0.220786  0.651429
# 385970  0.481481  0.131494  0.110953  0.131500  0.611429
# 385971  0.000000  0.172078  0.128023  0.172071  0.668571
# 385972  0.296296  0.251623  0.213371  0.251607  0.582857
# 385973  0.703704  0.139610  0.128023  0.139607  0.594286
#
# [385974 rows x 5 columns]

# %%
df_s.boxplot()

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

# %%
norm_array = scaler.fit_transform(df)

# %%
norm_array
# Out:
# array([[0.25925926, 0.24512987, 0.20625889, 0.24514286, 0.68      ],
#        [0.56790123, 0.19642857, 0.19345661, 0.19642857, 0.53714286],
#        [0.40740741, 0.28571429, 0.24182077, 0.28571429, 0.69714286],
#        ...,
#        [0.        , 0.17207792, 0.12802276, 0.17207143, 0.66857143],
#        [0.2962963 , 0.25162338, 0.21337127, 0.25160714, 0.58285714],
#        [0.7037037 , 0.13961039, 0.12802276, 0.13960714, 0.59428571]])

# %%
df_s = pd.DataFrame(norm_array, columns=df.columns)
df_s
# Out:
#              age   weight2   wtyrago     wtkg2      htm3
# 0       0.259259  0.245130  0.206259  0.245143  0.680000
# 1       0.567901  0.196429  0.193457  0.196429  0.537143
# 2       0.407407  0.285714  0.241821  0.285714  0.697143
# 3       0.209877  0.155844  0.120910  0.155857  0.622857
# 4       0.543210  0.180195  0.149360  0.180179  0.640000
# ...          ...       ...       ...       ...       ...
# 385969  0.530864  0.220779  0.199147  0.220786  0.651429
# 385970  0.481481  0.131494  0.110953  0.131500  0.611429
# 385971  0.000000  0.172078  0.128023  0.172071  0.668571
# 385972  0.296296  0.251623  0.213371  0.251607  0.582857
# 385973  0.703704  0.139610  0.128023  0.139607  0.594286
#
# [385974 rows x 5 columns]

# %%
df_s.boxplot()
